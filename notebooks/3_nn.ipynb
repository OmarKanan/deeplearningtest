# %%
import pickle
import numpy as np
import pandas as pd

from collections import Counter

from sklearn.metrics import f1_score, make_scorer, confusion_matrix, \
    classification_report
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_val_score, \
    StratifiedShuffleSplit, RandomizedSearchCV
from sklearn.neural_network import MLPClassifier


import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)

# %matplotlib inline

# %% [markdown]
# # Data

# %%
with open("../Data/Learn/labels.pkl", "rb") as f:
    learn_labels = pickle.load(f)

with open("../Data/Learn/sequences.pkl", "rb") as f:
    learn_sequences = pickle.load(f)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    learn_sequences, learn_labels, test_size=0.3,
    shuffle=True, stratify=learn_labels, random_state=42
)

# %% [markdown]
# # Model

# %%
def tokens_to_str(tokens):
    return list(map(str, tokens))

# %%
vectorizer = CountVectorizer(lowercase=False, tokenizer=tokens_to_str, ngram_range=(1, 2))
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# %%
def convert_sparse_matrix_to_sparse_tensor(X):
    coo = X.tocoo()
    indices = np.mat([coo.row, coo.col]).transpose()
    return tf.SparseTensorValue(indices, coo.data, coo.shape)

X_train_tensor = convert_sparse_matrix_to_sparse_tensor(X_train_vect)

# %%
def train_input_fn(features, labels, batch_size):
    dataset = tf.data.Dataset.from_tensors((features, labels))
    dataset = dataset.shuffle(1000).repeat().batch(batch_size)
    return dataset.make_one_shot_iterator().get_next()

inp = train_input_fn(X_train_tensor, y_train, batch_size=128)

# %%
tf.reset_default_graph()
vector_feature_column = tf.feature_column.numeric_column(key="x",
                                                         shape=X_train_tensor.shape[1])
classifier = tf.estimator.DNNClassifier(
    feature_columns=[vector_feature_column],
    hidden_units=[10, 10],
    n_classes=2,
)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /home/omar/tmp/tmpu8kbo5vg
# INFO:tensorflow:Using config: {'_model_dir': '/home/omar/tmp/tmpu8kbo5vg', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fbd653cbba8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
classifier.train(lambda : inp, steps=2)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-2bcbeabc693d> in <module>()
# ----> 1 classifier.train(lambda : inp, steps=2)
#
# /home/omar/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     361
#     362     saving_listeners = _check_listeners_type(saving_listeners)
# --> 363     loss = self._train_model(input_fn, hooks, saving_listeners)
#     364     logging.info('Loss for final step: %s.', loss)
#     365     return self
#
# /home/omar/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#     841       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#     842     else:
# --> 843       return self._train_model_default(input_fn, hooks, saving_listeners)
#     844
#     845   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /home/omar/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#     854       worker_hooks.extend(input_hooks)
#     855       estimator_spec = self._call_model_fn(
# --> 856           features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#     857       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#     858                                              hooks, global_step_tensor,
#
# /home/omar/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#     829
#     830     logging.info('Calling model_fn.')
# --> 831     model_fn_results = self._model_fn(features=features, **kwargs)
#     832     logging.info('Done calling model_fn.')
#     833
#
# /home/omar/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     345           dropout=dropout,
#     346           input_layer_partitioner=input_layer_partitioner,
# --> 347           config=config)
#     348
#     349     super(DNNClassifier, self).__init__(
#
# /home/omar/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config)
#     157   if not isinstance(features, dict):
#     158     raise ValueError('features should be a dictionary of `Tensor`s. '
# --> 159                      'Given type: {}'.format(type(features)))
#     160
#     161   optimizer = optimizers.get_optimizer_instance(
#
# ValueError: features should be a dictionary of `Tensor`s. Given type: <class 'tensorflow.python.framework.ops.Tensor'>

# %% [markdown]
# # Model

# %%
def my_model_fn(features, labels, mode):
    logits = compute_logits(features)
    predicted_labels = tf.argmax(logits, axis=1)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions = {"classes": predicted_labels, "probabilities": tf.nn.softmax(logits)}
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
        train_op = optimizer.minimize(loss=loss, global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)
    
    if mode == tf.estimator.ModeKeys.EVAL:
        eval_metric_ops = {"accuracy": score(labels, predicted_labels)}
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

def compute_logits(features):
    logits = tf.layers.dense(flat, units=2, activation=tf.nn.relu)
    return logits

def score(labels, predictions):
    return tf.metrics.accuracy(labels, predictions)

# %%
classifier = tf.estimator.Estimator(model_fn=my_model_fn, model_dir="checkpoints14")
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'checkpoints14', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1631292588>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x=np.array(padded_sequences),
    y=np.array(hot_labels),
    batch_size=128,
    num_epochs=10,
    shuffle=True
)

test_input_fn = tf.estimator.inputs.numpy_input_fn(
    x=np.array(padded_sequences),
    y=np.array(hot_labels),
    batch_size=len(hot_labels),
    shuffle=True
)

# %%
classifier.train(
    input_fn=train_input_fn,
)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into checkpoints14/model.ckpt.
# INFO:tensorflow:loss = 0.6913747787475586, step = 1
# INFO:tensorflow:global_step/sec: 171.892
# INFO:tensorflow:loss = 0.3540460467338562, step = 101 (0.582 sec)
# INFO:tensorflow:global_step/sec: 218.991
# INFO:tensorflow:loss = 0.3380691409111023, step = 201 (0.457 sec)
# INFO:tensorflow:global_step/sec: 220.418
# INFO:tensorflow:loss = 0.5283647179603577, step = 301 (0.454 sec)
# INFO:tensorflow:global_step/sec: 219.47
# INFO:tensorflow:loss = 0.9800107479095459, step = 401 (0.456 sec)
# INFO:tensorflow:global_step/sec: 218.623
# INFO:tensorflow:loss = 0.10859549790620804, step = 501 (0.457 sec)
# INFO:tensorflow:Saving checkpoints for 547 into checkpoints14/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.13887634873390198.

# %%
list(classifier.predict(
    input_fn=test_input_fn,
))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from checkpoints14/model.ckpt-547
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'classes': 1, 'probabilities': array([0.18624519, 0.81375481])},
#  {'classes': 1, 'probabilities': array([0.09213663, 0.90786337])},
#  {'classes': 1, 'probabilities': array([0.10569803, 0.89430197])},
#  {'classes': 1, 'probabilities': array([0.08121251, 0.91878749])},
#  {'classes': 1, 'probabilities': array([0.13793903, 0.86206097])},
#  {'classes': 1, 'probabilities': array([0.13340942, 0.86659058])},
#  {'classes': 1, 'probabilities': array([0.0958954, 0.9041046])},
#  {'classes': 1, 'probabilities': array([0.07924536, 0.92075464])},
#  {'classes': 1, 'probabilities': array([0.08732024, 0.91267976])},
#  {'classes': 1, 'probabilities': array([0.1042783, 0.8957217])},
#  {'classes': 1, 'probabilities': array([0.16692035, 0.83307965])},
#  {'classes': 1, 'probabilities': array([0.05728464, 0.94271536])},
#  {'classes': 1, 'probabilities': array([0.0987131, 0.9012869])},
#  {'classes': 1, 'probabilities': array([0.09571445, 0.90428555])},
#  {'classes': 1, 'probabilities': array([0.19438799, 0.80561201])},
#  {'classes': 1, 'probabilities': array([0.11363168, 0.88636832])},
#  {'classes': 1, 'probabilities': array([0.08812117, 0.91187883])},
#  {'classes': 1, 'probabilities': array([0.07835376, 0.92164624])},
#  {'classes': 1, 'probabilities': array([0.04568958, 0.95431042])},
#  {'classes': 1, 'probabilities': array([0.13536529, 0.86463471])},
#  {'classes': 1, 'probabilities': array([0.14939644, 0.85060356])},
#  {'classes': 1, 'probabilities': array([0.11093385, 0.88906615])},
#  {'classes': 1, 'probabilities': array([0.1613592, 0.8386408])},
#  {'classes': 1, 'probabilities': array([0.16703387, 0.83296613])},
#  {'classes': 1, 'probabilities': array([0.1170044, 0.8829956])},
#  {'classes': 1, 'probabilities': array([0.10551735, 0.89448265])},
#  {'classes': 1, 'probabilities': array([0.0927019, 0.9072981])},
#  {'classes': 1, 'probabilities': array([0.08444507, 0.91555493])},
#  {'classes': 1, 'probabilities': array([0.10569822, 0.89430178])},
#  {'classes': 1, 'probabilities': array([0.11687566, 0.88312434])},
#  {'classes': 1, 'probabilities': array([0.08749809, 0.91250191])},
#  {'classes': 1, 'probabilities': array([0.08743808, 0.91256192])},
#  {'classes': 1, 'probabilities': array([0.14704593, 0.85295407])},
#  {'classes': 1, 'probabilities': array([0.17726387, 0.82273613])},
#  {'classes': 1, 'probabilities': array([0.1324003, 0.8675997])},
#  {'classes': 1, 'probabilities': array([0.14981701, 0.85018299])},
#  {'classes': 1, 'probabilities': array([0.09629127, 0.90370873])},
#  {'classes': 1, 'probabilities': array([0.1287279, 0.8712721])},
#  {'classes': 1, 'probabilities': array([0.08146412, 0.91853588])},
#  {'classes': 1, 'probabilities': array([0.12502823, 0.87497177])},
#  {'classes': 1, 'probabilities': array([0.05949398, 0.94050602])},
#  {'classes': 1, 'probabilities': array([0.1548076, 0.8451924])},
#  {'classes': 1, 'probabilities': array([0.13209386, 0.86790614])},
#  {'classes': 1, 'probabilities': array([0.13884382, 0.86115618])},
#  {'classes': 1, 'probabilities': array([0.16370332, 0.83629668])},
#  {'classes': 1, 'probabilities': array([0.21642519, 0.78357481])},
#  {'classes': 1, 'probabilities': array([0.15336734, 0.84663266])},
#  {'classes': 1, 'probabilities': array([0.12381766, 0.87618234])},
#  {'classes': 1, 'probabilities': array([0.06287308, 0.93712692])},
#  {'classes': 1, 'probabilities': array([0.13579822, 0.86420178])},
#  {'classes': 1, 'probabilities': array([0.08276175, 0.91723825])},
#  {'classes': 1, 'probabilities': array([0.15969794, 0.84030206])},
#  {'classes': 1, 'probabilities': array([0.10556829, 0.89443171])},
#  {'classes': 1, 'probabilities': array([0.13337061, 0.86662939])},
#  {'classes': 1, 'probabilities': array([0.08458494, 0.91541506])},
#  {'classes': 1, 'probabilities': array([0.12075911, 0.87924089])},
#  {'classes': 1, 'probabilities': array([0.07769494, 0.92230506])},
#  {'classes': 1, 'probabilities': array([0.09565833, 0.90434167])},
#  {'classes': 1, 'probabilities': array([0.14114877, 0.85885123])},
#  {'classes': 1, 'probabilities': array([0.13000439, 0.86999561])},
#  {'classes': 1, 'probabilities': array([0.12447686, 0.87552314])},
#  {'classes': 1, 'probabilities': array([0.12098767, 0.87901233])},
#  {'classes': 1, 'probabilities': array([0.15187926, 0.84812074])},
#  {'classes': 1, 'probabilities': array([0.13575056, 0.86424944])},
#  {'classes': 1, 'probabilities': array([0.13685658, 0.86314342])},
#  {'classes': 1, 'probabilities': array([0.18691793, 0.81308207])},
#  {'classes': 1, 'probabilities': array([0.18449853, 0.81550147])},
#  {'classes': 1, 'probabilities': array([0.11845685, 0.88154315])},
#  {'classes': 1, 'probabilities': array([0.15789427, 0.84210573])},
#  {'classes': 1, 'probabilities': array([0.09407235, 0.90592765])},
#  {'classes': 1, 'probabilities': array([0.1731492, 0.8268508])},
#  {'classes': 1, 'probabilities': array([0.14261972, 0.85738028])},
#  {'classes': 1, 'probabilities': array([0.16854156, 0.83145844])},
#  {'classes': 1, 'probabilities': array([0.10756479, 0.89243521])},
#  {'classes': 1, 'probabilities': array([0.10694852, 0.89305148])},
#  {'classes': 1, 'probabilities': array([0.12300654, 0.87699346])},
#  {'classes': 1, 'probabilities': array([0.14267346, 0.85732654])},
#  {'classes': 1, 'probabilities': array([0.13578751, 0.86421249])},
#  {'classes': 1, 'probabilities': array([0.1557138, 0.8442862])},
#  {'classes': 1, 'probabilities': array([0.11408643, 0.88591357])},
#  {'classes': 1, 'probabilities': array([0.09053564, 0.90946436])},
#  {'classes': 1, 'probabilities': array([0.17439338, 0.82560662])},
#  {'classes': 1, 'probabilities': array([0.09212397, 0.90787603])},
#  {'classes': 1, 'probabilities': array([0.14544076, 0.85455924])},
#  {'classes': 1, 'probabilities': array([0.14653997, 0.85346003])},
#  {'classes': 1, 'probabilities': array([0.09840794, 0.90159206])},
#  {'classes': 1, 'probabilities': array([0.15037172, 0.84962828])},
#  {'classes': 1, 'probabilities': array([0.12079328, 0.87920672])},
#  {'classes': 1, 'probabilities': array([0.09414247, 0.90585753])},
#  {'classes': 1, 'probabilities': array([0.14994953, 0.85005047])},
#  {'classes': 1, 'probabilities': array([0.13648671, 0.86351329])},
#  {'classes': 1, 'probabilities': array([0.12690281, 0.87309719])},
#  {'classes': 1, 'probabilities': array([0.0918788, 0.9081212])},
#  {'classes': 1, 'probabilities': array([0.18898199, 0.81101801])},
#  {'classes': 1, 'probabilities': array([0.07569678, 0.92430322])},
#  {'classes': 1, 'probabilities': array([0.13334094, 0.86665906])},
#  {'classes': 1, 'probabilities': array([0.05091058, 0.94908942])},
#  {'classes': 1, 'probabilities': array([0.18737793, 0.81262207])},
#  {'classes': 1, 'probabilities': array([0.15130316, 0.84869684])},
#  {'classes': 1, 'probabilities': array([0.19791676, 0.80208324])},
#  {'classes': 1, 'probabilities': array([0.17233908, 0.82766092])},
#  {'classes': 1, 'probabilities': array([0.03803158, 0.96196842])},
#  {'classes': 1, 'probabilities': array([0.11781389, 0.88218611])},
#  {'classes': 1, 'probabilities': array([0.08416821, 0.91583179])},
#  {'classes': 1, 'probabilities': array([0.20157183, 0.79842817])},
#  {'classes': 1, 'probabilities': array([0.07177455, 0.92822545])},
#  {'classes': 1, 'probabilities': array([0.12194164, 0.87805836])},
#  {'classes': 1, 'probabilities': array([0.07362127, 0.92637873])},
#  {'classes': 1, 'probabilities': array([0.13079016, 0.86920984])},
#  {'classes': 1, 'probabilities': array([0.13872067, 0.86127933])},
#  {'classes': 1, 'probabilities': array([0.1467908, 0.8532092])},
#  {'classes': 1, 'probabilities': array([0.16163358, 0.83836642])},
#  {'classes': 1, 'probabilities': array([0.12378902, 0.87621098])},
#  {'classes': 1, 'probabilities': array([0.12923215, 0.87076785])},
#  {'classes': 1, 'probabilities': array([0.12349761, 0.87650239])},
#  {'classes': 1, 'probabilities': array([0.0907781, 0.9092219])},
#  {'classes': 1, 'probabilities': array([0.13072224, 0.86927776])},
#  {'classes': 1, 'probabilities': array([0.1448529, 0.8551471])},
#  {'classes': 1, 'probabilities': array([0.10600763, 0.89399237])},
#  {'classes': 1, 'probabilities': array([0.16706528, 0.83293472])},
#  {'classes': 1, 'probabilities': array([0.0969149, 0.9030851])},
#  {'classes': 1, 'probabilities': array([0.07367161, 0.92632839])},
#  {'classes': 1, 'probabilities': array([0.19698771, 0.80301229])},
#  {'classes': 1, 'probabilities': array([0.04645808, 0.95354192])},
#  {'classes': 1, 'probabilities': array([0.13626013, 0.86373987])},
#  {'classes': 1, 'probabilities': array([0.06860509, 0.93139491])},
#  {'classes': 1, 'probabilities': array([0.12523951, 0.87476049])},
#  {'classes': 1, 'probabilities': array([0.16435771, 0.83564229])},
#  {'classes': 1, 'probabilities': array([0.08781165, 0.91218835])},
#  {'classes': 1, 'probabilities': array([0.16309741, 0.83690259])},
#  {'classes': 1, 'probabilities': array([0.09477479, 0.90522521])},
#  {'classes': 1, 'probabilities': array([0.1971596, 0.8028404])},
#  {'classes': 1, 'probabilities': array([0.1222868, 0.8777132])},
#  {'classes': 1, 'probabilities': array([0.05615775, 0.94384225])},
#  {'classes': 1, 'probabilities': array([0.07322137, 0.92677863])},
#  {'classes': 1, 'probabilities': array([0.09408992, 0.90591008])},
#  {'classes': 1, 'probabilities': array([0.08885216, 0.91114784])},
#  {'classes': 1, 'probabilities': array([0.13787396, 0.86212604])},
#  {'classes': 1, 'probabilities': array([0.0950966, 0.9049034])},
#  {'classes': 1, 'probabilities': array([0.07351877, 0.92648123])},
#  {'classes': 1, 'probabilities': array([0.15761689, 0.84238311])},
#  {'classes': 1, 'probabilities': array([0.12478735, 0.87521265])},
#  {'classes': 1, 'probabilities': array([0.16720279, 0.83279721])},
#  {'classes': 1, 'probabilities': array([0.08732433, 0.91267567])},
#  {'classes': 1, 'probabilities': array([0.12225073, 0.87774927])},
#  {'classes': 1, 'probabilities': array([0.08773604, 0.91226396])},
#  {'classes': 1, 'probabilities': array([0.11468573, 0.88531427])},
#  {'classes': 1, 'probabilities': array([0.14510576, 0.85489424])},
#  {'classes': 1, 'probabilities': array([0.17975907, 0.82024093])},
#  {'classes': 1, 'probabilities': array([0.19576561, 0.80423439])},
#  {'classes': 1, 'probabilities': array([0.17566714, 0.82433286])},
#  {'classes': 1, 'probabilities': array([0.09324467, 0.90675533])},
#  {'classes': 1, 'probabilities': array([0.21361495, 0.78638505])},
#  {'classes': 1, 'probabilities': array([0.16165231, 0.83834769])},
#  {'classes': 1, 'probabilities': array([0.15408311, 0.84591689])},
#  {'classes': 1, 'probabilities': array([0.19103909, 0.80896091])},
#  {'classes': 1, 'probabilities': array([0.10566889, 0.89433111])},
#  {'classes': 1, 'probabilities': array([0.14104875, 0.85895125])},
#  {'classes': 1, 'probabilities': array([0.11914582, 0.88085418])},
#  {'classes': 1, 'probabilities': array([0.12447002, 0.87552998])},
#  {'classes': 1, 'probabilities': array([0.07352676, 0.92647324])},
#  {'classes': 1, 'probabilities': array([0.18070779, 0.81929221])},
#  {'classes': 1, 'probabilities': array([0.14482657, 0.85517343])},
#  {'classes': 1, 'probabilities': array([0.08316568, 0.91683432])},
#  {'classes': 1, 'probabilities': array([0.15138855, 0.84861145])},
#  {'classes': 1, 'probabilities': array([0.09828679, 0.90171321])},
#  {'classes': 1, 'probabilities': array([0.08464222, 0.91535778])},
#  {'classes': 1, 'probabilities': array([0.10949359, 0.89050641])},
#  {'classes': 1, 'probabilities': array([0.16526661, 0.83473339])},
#  {'classes': 1, 'probabilities': array([0.12872817, 0.87127183])},
#  {'classes': 1, 'probabilities': array([0.12358151, 0.87641849])},
#  {'classes': 1, 'probabilities': array([0.12211732, 0.87788268])},
#  {'classes': 1, 'probabilities': array([0.15665197, 0.84334803])},
#  {'classes': 1, 'probabilities': array([0.12995298, 0.87004702])},
#  {'classes': 1, 'probabilities': array([0.13308899, 0.86691101])},
#  {'classes': 1, 'probabilities': array([0.16385284, 0.83614716])},
#  {'classes': 1, 'probabilities': array([0.1501499, 0.8498501])},
#  {'classes': 1, 'probabilities': array([0.14705806, 0.85294194])},
#  {'classes': 1, 'probabilities': array([0.09121856, 0.90878144])},
#  {'classes': 1, 'probabilities': array([0.13750105, 0.86249895])},
#  {'classes': 1, 'probabilities': array([0.16230724, 0.83769276])},
#  {'classes': 1, 'probabilities': array([0.12789702, 0.87210298])},
#  {'classes': 1, 'probabilities': array([0.07373792, 0.92626208])},
#  {'classes': 1, 'probabilities': array([0.06294204, 0.93705796])},
#  {'classes': 1, 'probabilities': array([0.09981797, 0.90018203])},
#  {'classes': 1, 'probabilities': array([0.15146303, 0.84853697])},
#  {'classes': 1, 'probabilities': array([0.14243774, 0.85756226])},
#  {'classes': 1, 'probabilities': array([0.14826659, 0.85173341])},
#  {'classes': 1, 'probabilities': array([0.08692789, 0.91307211])},
#  {'classes': 1, 'probabilities': array([0.13616615, 0.86383385])},
#  {'classes': 1, 'probabilities': array([0.14995337, 0.85004663])},
#  {'classes': 1, 'probabilities': array([0.14895453, 0.85104547])},
#  {'classes': 1, 'probabilities': array([0.12326811, 0.87673189])},
#  {'classes': 1, 'probabilities': array([0.17618618, 0.82381382])},
#  {'classes': 1, 'probabilities': array([0.11105858, 0.88894142])},
#  {'classes': 1, 'probabilities': array([0.11047656, 0.88952344])},
#  {'classes': 1, 'probabilities': array([0.15073045, 0.84926955])},
#  {'classes': 1, 'probabilities': array([0.06880385, 0.93119615])},
#  {'classes': 1, 'probabilities': array([0.06961035, 0.93038965])},
#  {'classes': 1, 'probabilities': array([0.18397443, 0.81602557])},
#  {'classes': 1, 'probabilities': array([0.05132827, 0.94867173])},
#  {'classes': 1, 'probabilities': array([0.1490162, 0.8509838])},
#  {'classes': 1, 'probabilities': array([0.09168944, 0.90831056])},
#  {'classes': 1, 'probabilities': array([0.11742896, 0.88257104])},
#  {'classes': 1, 'probabilities': array([0.0867992, 0.9132008])},
#  {'classes': 1, 'probabilities': array([0.16081566, 0.83918434])},
#  {'classes': 1, 'probabilities': array([0.12341394, 0.87658606])},
#  {'classes': 1, 'probabilities': array([0.07394478, 0.92605522])},
#  {'classes': 1, 'probabilities': array([0.14048202, 0.85951798])},
#  {'classes': 1, 'probabilities': array([0.14381102, 0.85618898])},
#  {'classes': 1, 'probabilities': array([0.1719354, 0.8280646])},
#  {'classes': 1, 'probabilities': array([0.13539874, 0.86460126])},
#  {'classes': 1, 'probabilities': array([0.11424379, 0.88575621])},
#  {'classes': 1, 'probabilities': array([0.10088363, 0.89911637])},
#  {'classes': 1, 'probabilities': array([0.18003014, 0.81996986])},
#  {'classes': 1, 'probabilities': array([0.08735857, 0.91264143])},
#  {'classes': 1, 'probabilities': array([0.17684473, 0.82315527])},
#  {'classes': 1, 'probabilities': array([0.1024493, 0.8975507])},
#  {'classes': 1, 'probabilities': array([0.13434988, 0.86565012])},
#  {'classes': 1, 'probabilities': array([0.21298723, 0.78701277])},
#  {'classes': 1, 'probabilities': array([0.19251436, 0.80748564])},
#  {'classes': 1, 'probabilities': array([0.12318063, 0.87681937])},
#  {'classes': 1, 'probabilities': array([0.12795991, 0.87204009])},
#  {'classes': 1, 'probabilities': array([0.08062557, 0.91937443])},
#  {'classes': 1, 'probabilities': array([0.1552014, 0.8447986])},
#  {'classes': 1, 'probabilities': array([0.12767833, 0.87232167])},
#  {'classes': 1, 'probabilities': array([0.17669248, 0.82330752])},
#  {'classes': 1, 'probabilities': array([0.08261203, 0.91738797])},
#  {'classes': 1, 'probabilities': array([0.12977042, 0.87022958])},
#  {'classes': 1, 'probabilities': array([0.15045224, 0.84954776])},
#  {'classes': 1, 'probabilities': array([0.19866655, 0.80133345])},
#  {'classes': 1, 'probabilities': array([0.09768495, 0.90231505])},
#  {'classes': 1, 'probabilities': array([0.17221009, 0.82778991])},
#  {'classes': 1, 'probabilities': array([0.06741161, 0.93258839])},
#  {'classes': 1, 'probabilities': array([0.08107051, 0.91892949])},
#  {'classes': 1, 'probabilities': array([0.10144171, 0.89855829])},
#  {'classes': 1, 'probabilities': array([0.13935854, 0.86064146])},
#  {'classes': 1, 'probabilities': array([0.11082683, 0.88917317])},
#  {'classes': 1, 'probabilities': array([0.15061433, 0.84938567])},
#  {'classes': 1, 'probabilities': array([0.1690603, 0.8309397])},
#  {'classes': 1, 'probabilities': array([0.11365168, 0.88634832])},
#  {'classes': 1, 'probabilities': array([0.12722256, 0.87277744])},
#  {'classes': 1, 'probabilities': array([0.10825643, 0.89174357])},
#  {'classes': 1, 'probabilities': array([0.16774493, 0.83225507])},
#  {'classes': 1, 'probabilities': array([0.07352676, 0.92647324])},
#  {'classes': 1, 'probabilities': array([0.18462755, 0.81537245])},
#  {'classes': 1, 'probabilities': array([0.07443382, 0.92556618])},
#  {'classes': 1, 'probabilities': array([0.12769731, 0.87230269])},
#  {'classes': 1, 'probabilities': array([0.0720426, 0.9279574])},
#  {'classes': 1, 'probabilities': array([0.21004018, 0.78995982])},
#  {'classes': 1, 'probabilities': array([0.07930803, 0.92069197])},
#  {'classes': 1, 'probabilities': array([0.08280278, 0.91719722])},
#  {'classes': 1, 'probabilities': array([0.14613515, 0.85386485])},
#  {'classes': 1, 'probabilities': array([0.11605555, 0.88394445])},
#  {'classes': 1, 'probabilities': array([0.06193587, 0.93806413])},
#  {'classes': 1, 'probabilities': array([0.08887651, 0.91112349])},
#  {'classes': 1, 'probabilities': array([0.1060848, 0.8939152])},
#  {'classes': 1, 'probabilities': array([0.06119293, 0.93880707])},
#  {'classes': 1, 'probabilities': array([0.1267349, 0.8732651])},
#  {'classes': 1, 'probabilities': array([0.05189486, 0.94810514])},
#  {'classes': 1, 'probabilities': array([0.1464884, 0.8535116])},
#  {'classes': 1, 'probabilities': array([0.09848657, 0.90151343])},
#  {'classes': 1, 'probabilities': array([0.12303635, 0.87696365])},
#  {'classes': 1, 'probabilities': array([0.07947294, 0.92052706])},
#  {'classes': 1, 'probabilities': array([0.14560105, 0.85439895])},
#  {'classes': 1, 'probabilities': array([0.13879537, 0.86120463])},
#  {'classes': 1, 'probabilities': array([0.15715476, 0.84284524])},
#  {'classes': 1, 'probabilities': array([0.17006922, 0.82993078])},
#  {'classes': 1, 'probabilities': array([0.14415086, 0.85584914])},
#  {'classes': 1, 'probabilities': array([0.2011246, 0.7988754])},
#  {'classes': 1, 'probabilities': array([0.10784394, 0.89215606])},
#  {'classes': 1, 'probabilities': array([0.21197107, 0.78802893])},
#  {'classes': 1, 'probabilities': array([0.06664194, 0.93335806])},
#  {'classes': 1, 'probabilities': array([0.13225724, 0.86774276])},
#  {'classes': 1, 'probabilities': array([0.21007236, 0.78992764])},
#  {'classes': 1, 'probabilities': array([0.11598321, 0.88401679])},
#  {'classes': 1, 'probabilities': array([0.13777019, 0.86222981])},
#  {'classes': 1, 'probabilities': array([0.07927512, 0.92072488])},
#  {'classes': 1, 'probabilities': array([0.09167696, 0.90832304])},
#  {'classes': 1, 'probabilities': array([0.10492141, 0.89507859])},
#  {'classes': 1, 'probabilities': array([0.11653595, 0.88346405])},
#  {'classes': 1, 'probabilities': array([0.09270037, 0.90729963])},
#  {'classes': 1, 'probabilities': array([0.1836702, 0.8163298])},
#  {'classes': 1, 'probabilities': array([0.12147825, 0.87852175])},
#  {'classes': 1, 'probabilities': array([0.08923269, 0.91076731])},
#  {'classes': 1, 'probabilities': array([0.09620248, 0.90379752])},
#  {'classes': 1, 'probabilities': array([0.09712018, 0.90287982])},
#  {'classes': 1, 'probabilities': array([0.12932386, 0.87067614])},
#  {'classes': 1, 'probabilities': array([0.1410762, 0.8589238])},
#  {'classes': 1, 'probabilities': array([0.18482823, 0.81517177])},
#  {'classes': 1, 'probabilities': array([0.12957714, 0.87042286])},
#  {'classes': 1, 'probabilities': array([0.07554562, 0.92445438])},
#  {'classes': 1, 'probabilities': array([0.13249283, 0.86750717])},
#  {'classes': 1, 'probabilities': array([0.08221241, 0.91778759])},
#  {'classes': 1, 'probabilities': array([0.14647562, 0.85352438])},
#  {'classes': 1, 'probabilities': array([0.13413736, 0.86586264])},
#  {'classes': 1, 'probabilities': array([0.18713986, 0.81286014])},
#  {'classes': 1, 'probabilities': array([0.08721632, 0.91278368])},
#  {'classes': 1, 'probabilities': array([0.14553641, 0.85446359])},
#  {'classes': 1, 'probabilities': array([0.059038, 0.940962])},
#  {'classes': 1, 'probabilities': array([0.12664288, 0.87335712])},
#  {'classes': 1, 'probabilities': array([0.13882145, 0.86117855])},
#  {'classes': 1, 'probabilities': array([0.10210016, 0.89789984])},
#  {'classes': 1, 'probabilities': array([0.16620613, 0.83379387])},
#  {'classes': 1, 'probabilities': array([0.13948076, 0.86051924])},
#  {'classes': 1, 'probabilities': array([0.12098259, 0.87901741])},
#  {'classes': 1, 'probabilities': array([0.05981769, 0.94018231])},
#  {'classes': 1, 'probabilities': array([0.13446963, 0.86553037])},
#  {'classes': 1, 'probabilities': array([0.13769839, 0.86230161])},
#  {'classes': 1, 'probabilities': array([0.0908674, 0.9091326])},
#  {'classes': 1, 'probabilities': array([0.15912674, 0.84087326])},
#  {'classes': 1, 'probabilities': array([0.10186123, 0.89813877])},
#  {'classes': 1, 'probabilities': array([0.13411943, 0.86588057])},
#  {'classes': 1, 'probabilities': array([0.15357752, 0.84642248])},
#  {'classes': 1, 'probabilities': array([0.17038645, 0.82961355])},
#  {'classes': 1, 'probabilities': array([0.10296278, 0.89703722])},
#  {'classes': 1, 'probabilities': array([0.10739209, 0.89260791])},
#  {'classes': 1, 'probabilities': array([0.09504511, 0.90495489])},
#  {'classes': 1, 'probabilities': array([0.10974851, 0.89025149])},
#  {'classes': 1, 'probabilities': array([0.07063039, 0.92936961])},
#  {'classes': 1, 'probabilities': array([0.12980605, 0.87019395])},
#  {'classes': 1, 'probabilities': array([0.13873922, 0.86126078])},
#  {'classes': 1, 'probabilities': array([0.09168732, 0.90831268])},
#  {'classes': 1, 'probabilities': array([0.17839574, 0.82160426])},
#  {'classes': 1, 'probabilities': array([0.14051365, 0.85948635])},
#  {'classes': 1, 'probabilities': array([0.06844759, 0.93155241])},
#  {'classes': 1, 'probabilities': array([0.11855304, 0.88144696])},
#  {'classes': 1, 'probabilities': array([0.14032231, 0.85967769])},
#  {'classes': 1, 'probabilities': array([0.15268526, 0.84731474])},
#  {'classes': 1, 'probabilities': array([0.14704391, 0.85295609])},
#  {'classes': 1, 'probabilities': array([0.10011326, 0.89988674])},
#  {'classes': 1, 'probabilities': array([0.06187336, 0.93812664])},
#  {'classes': 1, 'probabilities': array([0.08438035, 0.91561965])},
#  {'classes': 1, 'probabilities': array([0.10479473, 0.89520527])},
#  {'classes': 1, 'probabilities': array([0.19125365, 0.80874635])},
#  {'classes': 1, 'probabilities': array([0.18860631, 0.81139369])},
#  {'classes': 1, 'probabilities': array([0.11757458, 0.88242542])},
#  {'classes': 1, 'probabilities': array([0.11830695, 0.88169305])},
#  {'classes': 1, 'probabilities': array([0.08355082, 0.91644918])},
#  {'classes': 1, 'probabilities': array([0.06664142, 0.93335858])},
#  {'classes': 1, 'probabilities': array([0.1536102, 0.8463898])},
#  {'classes': 1, 'probabilities': array([0.08444507, 0.91555493])},
#  {'classes': 1, 'probabilities': array([0.14030386, 0.85969614])},
#  {'classes': 1, 'probabilities': array([0.16073857, 0.83926143])},
#  {'classes': 1, 'probabilities': array([0.07094075, 0.92905925])},
#  {'classes': 1, 'probabilities': array([0.16029565, 0.83970435])},
#  {'classes': 1, 'probabilities': array([0.08790041, 0.91209959])},
#  {'classes': 1, 'probabilities': array([0.10564594, 0.89435406])},
#  {'classes': 1, 'probabilities': array([0.12764765, 0.87235235])},
#  {'classes': 1, 'probabilities': array([0.08627916, 0.91372084])},
#  {'classes': 1, 'probabilities': array([0.14740867, 0.85259133])},
#  {'classes': 1, 'probabilities': array([0.10824981, 0.89175019])},
#  {'classes': 1, 'probabilities': array([0.1713952, 0.8286048])},
#  {'classes': 1, 'probabilities': array([0.09895774, 0.90104226])},
#  {'classes': 1, 'probabilities': array([0.16824507, 0.83175493])},
#  {'classes': 1, 'probabilities': array([0.12834445, 0.87165555])},
#  {'classes': 1, 'probabilities': array([0.19067843, 0.80932157])},
#  {'classes': 1, 'probabilities': array([0.10743138, 0.89256862])},
#  {'classes': 1, 'probabilities': array([0.09477479, 0.90522521])},
#  {'classes': 1, 'probabilities': array([0.0767866, 0.9232134])},
#  {'classes': 1, 'probabilities': array([0.05670423, 0.94329577])},
#  {'classes': 1, 'probabilities': array([0.13582651, 0.86417349])},
#  {'classes': 1, 'probabilities': array([0.09400979, 0.90599021])},
#  {'classes': 1, 'probabilities': array([0.06733636, 0.93266364])},
#  {'classes': 1, 'probabilities': array([0.16080424, 0.83919576])},
#  {'classes': 1, 'probabilities': array([0.15632799, 0.84367201])},
#  {'classes': 1, 'probabilities': array([0.06613393, 0.93386607])},
#  {'classes': 1, 'probabilities': array([0.1501726, 0.8498274])},
#  {'classes': 1, 'probabilities': array([0.18140046, 0.81859954])},
#  {'classes': 1, 'probabilities': array([0.14027214, 0.85972786])},
#  {'classes': 1, 'probabilities': array([0.09652424, 0.90347576])},
#  {'classes': 1, 'probabilities': array([0.10153625, 0.89846375])},
#  {'classes': 1, 'probabilities': array([0.07352676, 0.92647324])},
#  {'classes': 1, 'probabilities': array([0.09807612, 0.90192388])},
#  {'classes': 1, 'probabilities': array([0.15459526, 0.84540474])},
#  {'classes': 1, 'probabilities': array([0.07739213, 0.92260787])},
#  {'classes': 1, 'probabilities': array([0.17487621, 0.82512379])},
#  {'classes': 1, 'probabilities': array([0.09601715, 0.90398285])},
#  {'classes': 1, 'probabilities': array([0.10153402, 0.89846598])},
#  {'classes': 1, 'probabilities': array([0.09797867, 0.90202133])},
#  {'classes': 1, 'probabilities': array([0.15052505, 0.84947495])},
#  {'classes': 1, 'probabilities': array([0.10101046, 0.89898954])},
#  {'classes': 1, 'probabilities': array([0.05379435, 0.94620565])},
#  {'classes': 1, 'probabilities': array([0.06120604, 0.93879396])},
#  {'classes': 1, 'probabilities': array([0.11856668, 0.88143332])},
#  {'classes': 1, 'probabilities': array([0.06666416, 0.93333584])},
#  {'classes': 1, 'probabilities': array([0.12235199, 0.87764801])},
#  {'classes': 1, 'probabilities': array([0.14389691, 0.85610309])},
#  {'classes': 1, 'probabilities': array([0.06637838, 0.93362162])},
#  {'classes': 1, 'probabilities': array([0.17752373, 0.82247627])},
#  {'classes': 1, 'probabilities': array([0.13614871, 0.86385129])},
#  {'classes': 1, 'probabilities': array([0.08462703, 0.91537297])},
#  {'classes': 1, 'probabilities': array([0.14543705, 0.85456295])},
#  {'classes': 1, 'probabilities': array([0.12131298, 0.87868702])},
#  {'classes': 1, 'probabilities': array([0.10284613, 0.89715387])},
#  {'classes': 1, 'probabilities': array([0.12689252, 0.87310748])},
#  {'classes': 1, 'probabilities': array([0.14770696, 0.85229304])},
#  {'classes': 1, 'probabilities': array([0.20197269, 0.79802731])},
#  {'classes': 1, 'probabilities': array([0.12177954, 0.87822046])},
#  {'classes': 1, 'probabilities': array([0.12457213, 0.87542787])},
#  {'classes': 1, 'probabilities': array([0.07829757, 0.92170243])},
#  {'classes': 1, 'probabilities': array([0.07661486, 0.92338514])},
#  {'classes': 1, 'probabilities': array([0.14606537, 0.85393463])},
#  {'classes': 1, 'probabilities': array([0.10912557, 0.89087443])},
#  {'classes': 1, 'probabilities': array([0.13120906, 0.86879094])},
#  {'classes': 1, 'probabilities': array([0.22028969, 0.77971031])},
#  {'classes': 1, 'probabilities': array([0.09211231, 0.90788769])},
#  {'classes': 1, 'probabilities': array([0.0800524, 0.9199476])},
#  {'classes': 1, 'probabilities': array([0.07677038, 0.92322962])},
#  {'classes': 1, 'probabilities': array([0.17633297, 0.82366703])},
#  {'classes': 1, 'probabilities': array([0.11458943, 0.88541057])},
#  {'classes': 1, 'probabilities': array([0.14008142, 0.85991858])},
#  {'classes': 1, 'probabilities': array([0.06847044, 0.93152956])},
#  {'classes': 1, 'probabilities': array([0.07967045, 0.92032955])},
#  {'classes': 1, 'probabilities': array([0.14235109, 0.85764891])},
#  {'classes': 1, 'probabilities': array([0.13291543, 0.86708457])},
#  {'classes': 1, 'probabilities': array([0.18671534, 0.81328466])},
#  {'classes': 1, 'probabilities': array([0.07295913, 0.92704087])},
#  {'classes': 1, 'probabilities': array([0.1274764, 0.8725236])},
#  {'classes': 1, 'probabilities': array([0.14664381, 0.85335619])},
#  {'classes': 1, 'probabilities': array([0.126507, 0.873493])},
#  {'classes': 1, 'probabilities': array([0.07802229, 0.92197771])},
#  {'classes': 1, 'probabilities': array([0.10570939, 0.89429061])},
#  {'classes': 1, 'probabilities': array([0.08752103, 0.91247897])},
#  {'classes': 1, 'probabilities': array([0.07023376, 0.92976624])},
#  {'classes': 1, 'probabilities': array([0.1331202, 0.8668798])},
#  {'classes': 1, 'probabilities': array([0.20006907, 0.79993093])},
#  {'classes': 1, 'probabilities': array([0.11738556, 0.88261444])},
#  {'classes': 1, 'probabilities': array([0.16367002, 0.83632998])},
#  {'classes': 1, 'probabilities': array([0.11380044, 0.88619956])},
#  {'classes': 1, 'probabilities': array([0.08103902, 0.91896098])},
#  {'classes': 1, 'probabilities': array([0.13930407, 0.86069593])},
#  {'classes': 1, 'probabilities': array([0.14415378, 0.85584622])},
#  {'classes': 1, 'probabilities': array([0.0960412, 0.9039588])},
#  {'classes': 1, 'probabilities': array([0.16837645, 0.83162355])},
#  {'classes': 1, 'probabilities': array([0.10241108, 0.89758892])},
#  {'classes': 1, 'probabilities': array([0.15112981, 0.84887019])},
#  {'classes': 1, 'probabilities': array([0.13606815, 0.86393185])},
#  {'classes': 1, 'probabilities': array([0.08135705, 0.91864295])},
#  {'classes': 1, 'probabilities': array([0.10507017, 0.89492983])},
#  {'classes': 1, 'probabilities': array([0.15649858, 0.84350142])},
#  {'classes': 1, 'probabilities': array([0.08837121, 0.91162879])},
#  {'classes': 1, 'probabilities': array([0.1106205, 0.8893795])},
#  {'classes': 1, 'probabilities': array([0.16808311, 0.83191689])},
#  {'classes': 1, 'probabilities': array([0.14049395, 0.85950605])},
#  {'classes': 1, 'probabilities': array([0.11234775, 0.88765225])},
#  {'classes': 1, 'probabilities': array([0.15412069, 0.84587931])},
#  {'classes': 1, 'probabilities': array([0.16291375, 0.83708625])},
#  {'classes': 1, 'probabilities': array([0.13495276, 0.86504724])},
#  {'classes': 1, 'probabilities': array([0.1205044, 0.8794956])},
#  {'classes': 1, 'probabilities': array([0.16621576, 0.83378424])},
#  {'classes': 1, 'probabilities': array([0.11494554, 0.88505446])},
#  {'classes': 1, 'probabilities': array([0.11664519, 0.88335481])},
#  {'classes': 1, 'probabilities': array([0.08710929, 0.91289071])},
#  {'classes': 1, 'probabilities': array([0.13062897, 0.86937103])},
#  {'classes': 1, 'probabilities': array([0.06661116, 0.93338884])},
#  {'classes': 1, 'probabilities': array([0.13831007, 0.86168993])},
#  {'classes': 1, 'probabilities': array([0.12975804, 0.87024196])},
#  {'classes': 1, 'probabilities': array([0.1335266, 0.8664734])},
#  {'classes': 1, 'probabilities': array([0.10427691, 0.89572309])},
#  {'classes': 1, 'probabilities': array([0.07568613, 0.92431387])},
#  {'classes': 1, 'probabilities': array([0.13892583, 0.86107417])},
#  {'classes': 1, 'probabilities': array([0.16791892, 0.83208108])},
#  {'classes': 1, 'probabilities': array([0.08897965, 0.91102035])},
#  {'classes': 1, 'probabilities': array([0.11406079, 0.88593921])},
#  {'classes': 1, 'probabilities': array([0.10948956, 0.89051044])},
#  {'classes': 1, 'probabilities': array([0.14417248, 0.85582752])},
#  {'classes': 1, 'probabilities': array([0.16878282, 0.83121718])},
#  {'classes': 1, 'probabilities': array([0.09749136, 0.90250864])},
#  {'classes': 1, 'probabilities': array([0.11892392, 0.88107608])},
#  {'classes': 1, 'probabilities': array([0.11737965, 0.88262035])},
#  {'classes': 1, 'probabilities': array([0.114976, 0.885024])},
#  {'classes': 1, 'probabilities': array([0.15068905, 0.84931095])},
#  {'classes': 1, 'probabilities': array([0.10999501, 0.89000499])},
#  {'classes': 1, 'probabilities': array([0.11452461, 0.88547539])},
#  {'classes': 1, 'probabilities': array([0.14691038, 0.85308962])},
#  {'classes': 1, 'probabilities': array([0.1333193, 0.8666807])},
#  {'classes': 1, 'probabilities': array([0.15939297, 0.84060703])},
#  {'classes': 1, 'probabilities': array([0.08547324, 0.91452676])},
#  {'classes': 1, 'probabilities': array([0.10975243, 0.89024757])},
#  {'classes': 1, 'probabilities': array([0.11261943, 0.88738057])},
#  {'classes': 1, 'probabilities': array([0.15561991, 0.84438009])},
#  {'classes': 1, 'probabilities': array([0.06007841, 0.93992159])},
#  {'classes': 1, 'probabilities': array([0.14438616, 0.85561384])},
#  {'classes': 1, 'probabilities': array([0.09054404, 0.90945596])},
#  {'classes': 1, 'probabilities': array([0.1871383, 0.8128617])},
#  {'classes': 1, 'probabilities': array([0.15401764, 0.84598236])},
#  {'classes': 1, 'probabilities': array([0.07352676, 0.92647324])},
#  {'classes': 1, 'probabilities': array([0.1206098, 0.8793902])},
#  {'classes': 1, 'probabilities': array([0.12686433, 0.87313567])},
#  {'classes': 1, 'probabilities': array([0.11468035, 0.88531965])},
#  {'classes': 1, 'probabilities': array([0.07390381, 0.92609619])},
#  {'classes': 1, 'probabilities': array([0.08290828, 0.91709172])},
#  {'classes': 1, 'probabilities': array([0.20797867, 0.79202133])},
#  {'classes': 1, 'probabilities': array([0.12971427, 0.87028573])},
#  {'classes': 1, 'probabilities': array([0.08494432, 0.91505568])},
#  {'classes': 1, 'probabilities': array([0.11382441, 0.88617559])},
#  {'classes': 1, 'probabilities': array([0.19546665, 0.80453335])},
#  {'classes': 1, 'probabilities': array([0.12107848, 0.87892152])},
#  {'classes': 1, 'probabilities': array([0.10656424, 0.89343576])},
#  {'classes': 1, 'probabilities': array([0.13057864, 0.86942136])},
#  {'classes': 1, 'probabilities': array([0.13179832, 0.86820168])},
#  {'classes': 1, 'probabilities': array([0.11754551, 0.88245449])},
#  {'classes': 1, 'probabilities': array([0.14036638, 0.85963362])},
#  {'classes': 1, 'probabilities': array([0.04356357, 0.95643643])},
#  {'classes': 1, 'probabilities': array([0.14739701, 0.85260299])},
#  {'classes': 1, 'probabilities': array([0.13196981, 0.86803019])},
#  {'classes': 1, 'probabilities': array([0.08447493, 0.91552507])},
#  {'classes': 1, 'probabilities': array([0.16010414, 0.83989586])},
#  {'classes': 1, 'probabilities': array([0.09433578, 0.90566422])},
#  {'classes': 1, 'probabilities': array([0.12685834, 0.87314166])},
#  {'classes': 1, 'probabilities': array([0.10568299, 0.89431701])},
#  {'classes': 1, 'probabilities': array([0.0813368, 0.9186632])},
#  {'classes': 1, 'probabilities': array([0.13228781, 0.86771219])},
#  {'classes': 1, 'probabilities': array([0.10331712, 0.89668288])},
#  {'classes': 1, 'probabilities': array([0.11442355, 0.88557645])},
#  {'classes': 1, 'probabilities': array([0.13688304, 0.86311696])},
#  {'classes': 1, 'probabilities': array([0.11705892, 0.88294108])},
#  {'classes': 1, 'probabilities': array([0.16957482, 0.83042518])},
#  {'classes': 1, 'probabilities': array([0.05873888, 0.94126112])},
#  {'classes': 1, 'probabilities': array([0.15267059, 0.84732941])},
#  {'classes': 1, 'probabilities': array([0.09375559, 0.90624441])},
#  {'classes': 1, 'probabilities': array([0.0708132, 0.9291868])},
#  {'classes': 1, 'probabilities': array([0.13608746, 0.86391254])},
#  {'classes': 1, 'probabilities': array([0.09295874, 0.90704126])},
#  {'classes': 1, 'probabilities': array([0.08035107, 0.91964893])},
#  {'classes': 1, 'probabilities': array([0.13471398, 0.86528602])},
#  {'classes': 1, 'probabilities': array([0.13637575, 0.86362425])},
#  {'classes': 1, 'probabilities': array([0.17317708, 0.82682292])},
#  {'classes': 1, 'probabilities': array([0.13917861, 0.86082139])},
#  {'classes': 1, 'probabilities': array([0.1095903, 0.8904097])},
#  {'classes': 1, 'probabilities': array([0.19933259, 0.80066741])},
#  {'classes': 1, 'probabilities': array([0.08323741, 0.91676259])},
#  {'classes': 1, 'probabilities': array([0.12696639, 0.87303361])},
#  {'classes': 1, 'probabilities': array([0.1507184, 0.8492816])},
#  {'classes': 1, 'probabilities': array([0.12115542, 0.87884458])},
#  {'classes': 1, 'probabilities': array([0.15221823, 0.84778177])},
#  {'classes': 1, 'probabilities': array([0.17113944, 0.82886056])},
#  {'classes': 1, 'probabilities': array([0.17961519, 0.82038481])},
#  {'classes': 1, 'probabilities': array([0.07275185, 0.92724815])},
#  {'classes': 1, 'probabilities': array([0.09317007, 0.90682993])},
#  {'classes': 1, 'probabilities': array([0.19446734, 0.80553266])},
#  {'classes': 1, 'probabilities': array([0.11101254, 0.88898746])},
#  {'classes': 1, 'probabilities': array([0.1506334, 0.8493666])},
#  {'classes': 1, 'probabilities': array([0.15376854, 0.84623146])},
#  {'classes': 1, 'probabilities': array([0.15079571, 0.84920429])},
#  {'classes': 1, 'probabilities': array([0.15241184, 0.84758816])},
#  {'classes': 1, 'probabilities': array([0.23444345, 0.76555655])},
#  {'classes': 1, 'probabilities': array([0.14860172, 0.85139828])},
#  {'classes': 1, 'probabilities': array([0.1211627, 0.8788373])},
#  {'classes': 1, 'probabilities': array([0.10538229, 0.89461771])},
#  {'classes': 1, 'probabilities': array([0.11879636, 0.88120364])},
#  {'classes': 1, 'probabilities': array([0.12189318, 0.87810682])},
#  {'classes': 1, 'probabilities': array([0.05938759, 0.94061241])},
#  {'classes': 1, 'probabilities': array([0.08994197, 0.91005803])},
#  {'classes': 1, 'probabilities': array([0.1591234, 0.8408766])},
#  {'classes': 1, 'probabilities': array([0.13167533, 0.86832467])},
#  {'classes': 1, 'probabilities': array([0.11877947, 0.88122053])},
#  {'classes': 1, 'probabilities': array([0.06607605, 0.93392395])},
#  {'classes': 1, 'probabilities': array([0.10451604, 0.89548396])},
#  {'classes': 1, 'probabilities': array([0.12969866, 0.87030134])},
#  {'classes': 1, 'probabilities': array([0.09565833, 0.90434167])},
#  {'classes': 1, 'probabilities': array([0.12351032, 0.87648968])},
#  {'classes': 1, 'probabilities': array([0.17903215, 0.82096785])},
#  {'classes': 1, 'probabilities': array([0.16942979, 0.83057021])},
#  {'classes': 1, 'probabilities': array([0.08078525, 0.91921475])},
#  {'classes': 1, 'probabilities': array([0.08473704, 0.91526296])},
#  {'classes': 1, 'probabilities': array([0.09571471, 0.90428529])},
#  {'classes': 1, 'probabilities': array([0.05977735, 0.94022265])},
#  {'classes': 1, 'probabilities': array([0.13603377, 0.86396623])},
#  {'classes': 1, 'probabilities': array([0.14049092, 0.85950908])},
#  {'classes': 1, 'probabilities': array([0.10102415, 0.89897585])},
#  {'classes': 1, 'probabilities': array([0.15837526, 0.84162474])},
#  {'classes': 1, 'probabilities': array([0.08422683, 0.91577317])},
#  {'classes': 1, 'probabilities': array([0.09149215, 0.90850785])},
#  {'classes': 1, 'probabilities': array([0.18141508, 0.81858492])},
#  {'classes': 1, 'probabilities': array([0.18734174, 0.81265826])},
#  {'classes': 1, 'probabilities': array([0.17942679, 0.82057321])},
#  {'classes': 1, 'probabilities': array([0.09145126, 0.90854874])},
#  {'classes': 1, 'probabilities': array([0.16730841, 0.83269159])},
#  {'classes': 1, 'probabilities': array([0.08627916, 0.91372084])},
#  {'classes': 1, 'probabilities': array([0.11797478, 0.88202522])},
#  {'classes': 1, 'probabilities': array([0.15303361, 0.84696639])},
#  {'classes': 1, 'probabilities': array([0.11242622, 0.88757378])},
#  {'classes': 1, 'probabilities': array([0.12867421, 0.87132579])},
#  {'classes': 1, 'probabilities': array([0.14965843, 0.85034157])},
#  {'classes': 1, 'probabilities': array([0.07505304, 0.92494696])},
#  {'classes': 1, 'probabilities': array([0.21761128, 0.78238872])},
#  {'classes': 1, 'probabilities': array([0.06933109, 0.93066891])},
#  {'classes': 1, 'probabilities': array([0.09841308, 0.90158692])},
#  {'classes': 1, 'probabilities': array([0.10132476, 0.89867524])},
#  {'classes': 1, 'probabilities': array([0.04704209, 0.95295791])},
#  {'classes': 1, 'probabilities': array([0.11921278, 0.88078722])},
#  {'classes': 1, 'probabilities': array([0.05312664, 0.94687336])},
#  {'classes': 1, 'probabilities': array([0.16249954, 0.83750046])},
#  {'classes': 1, 'probabilities': array([0.21115747, 0.78884253])},
#  {'classes': 1, 'probabilities': array([0.09053564, 0.90946436])},
#  {'classes': 1, 'probabilities': array([0.11870011, 0.88129989])},
#  {'classes': 1, 'probabilities': array([0.1590442, 0.8409558])},
#  {'classes': 1, 'probabilities': array([0.12770575, 0.87229425])},
#  {'classes': 1, 'probabilities': array([0.10195461, 0.89804539])},
#  {'classes': 1, 'probabilities': array([0.06728775, 0.93271225])},
#  {'classes': 1, 'probabilities': array([0.12892105, 0.87107895])},
#  {'classes': 1, 'probabilities': array([0.13013836, 0.86986164])},
#  {'classes': 1, 'probabilities': array([0.17603407, 0.82396593])},
#  {'classes': 1, 'probabilities': array([0.09534877, 0.90465123])},
#  {'classes': 1, 'probabilities': array([0.07866478, 0.92133522])},
#  {'classes': 1, 'probabilities': array([0.12975997, 0.87024003])},
#  {'classes': 1, 'probabilities': array([0.14020851, 0.85979149])},
#  {'classes': 1, 'probabilities': array([0.12223751, 0.87776249])},
#  {'classes': 1, 'probabilities': array([0.10797659, 0.89202341])},
#  {'classes': 1, 'probabilities': array([0.15079062, 0.84920938])},
#  {'classes': 1, 'probabilities': array([0.14773959, 0.85226041])},
#  {'classes': 1, 'probabilities': array([0.20742041, 0.79257959])},
#  {'classes': 1, 'probabilities': array([0.17542625, 0.82457375])},
#  {'classes': 1, 'probabilities': array([0.11607841, 0.88392159])},
#  {'classes': 1, 'probabilities': array([0.12842325, 0.87157675])},
#  {'classes': 1, 'probabilities': array([0.13283291, 0.86716709])},
#  {'classes': 1, 'probabilities': array([0.18512795, 0.81487205])},
#  {'classes': 1, 'probabilities': array([0.1210422, 0.8789578])},
#  {'classes': 1, 'probabilities': array([0.06999397, 0.93000603])},
#  {'classes': 1, 'probabilities': array([0.12180531, 0.87819469])},
#  {'classes': 1, 'probabilities': array([0.1454015, 0.8545985])},
#  {'classes': 1, 'probabilities': array([0.09240671, 0.90759329])},
#  {'classes': 1, 'probabilities': array([0.0937395, 0.9062605])},
#  {'classes': 1, 'probabilities': array([0.11265587, 0.88734413])},
#  {'classes': 1, 'probabilities': array([0.15100634, 0.84899366])},
#  {'classes': 1, 'probabilities': array([0.18313809, 0.81686191])},
#  {'classes': 1, 'probabilities': array([0.09819992, 0.90180008])},
#  {'classes': 1, 'probabilities': array([0.11489018, 0.88510982])},
#  {'classes': 1, 'probabilities': array([0.12849085, 0.87150915])},
#  {'classes': 1, 'probabilities': array([0.08490158, 0.91509842])},
#  {'classes': 1, 'probabilities': array([0.15700354, 0.84299646])},
#  {'classes': 1, 'probabilities': array([0.17314773, 0.82685227])},
#  {'classes': 1, 'probabilities': array([0.10131345, 0.89868655])},
#  {'classes': 1, 'probabilities': array([0.14810164, 0.85189836])},
#  {'classes': 1, 'probabilities': array([0.14306708, 0.85693292])},
#  {'classes': 1, 'probabilities': array([0.15844683, 0.84155317])},
#  {'classes': 1, 'probabilities': array([0.08048899, 0.91951101])},
#  {'classes': 1, 'probabilities': array([0.13662388, 0.86337612])},
#  {'classes': 1, 'probabilities': array([0.09736026, 0.90263974])},
#  {'classes': 1, 'probabilities': array([0.09360987, 0.90639013])},
#  {'classes': 1, 'probabilities': array([0.19059573, 0.80940427])},
#  {'classes': 1, 'probabilities': array([0.13267937, 0.86732063])},
#  {'classes': 1, 'probabilities': array([0.15884145, 0.84115855])},
#  {'classes': 1, 'probabilities': array([0.06477032, 0.93522968])},
#  {'classes': 1, 'probabilities': array([0.08113343, 0.91886657])},
#  {'classes': 1, 'probabilities': array([0.15293455, 0.84706545])},
#  {'classes': 1, 'probabilities': array([0.06247939, 0.93752061])},
#  {'classes': 1, 'probabilities': array([0.1096355, 0.8903645])},
#  {'classes': 1, 'probabilities': array([0.08679302, 0.91320698])},
#  {'classes': 1, 'probabilities': array([0.17734181, 0.82265819])},
#  {'classes': 1, 'probabilities': array([0.11286502, 0.88713498])},
#  {'classes': 1, 'probabilities': array([0.04471557, 0.95528443])},
#  {'classes': 1, 'probabilities': array([0.09079633, 0.90920367])},
#  {'classes': 1, 'probabilities': array([0.11831974, 0.88168026])},
#  {'classes': 1, 'probabilities': array([0.07825581, 0.92174419])},
#  {'classes': 1, 'probabilities': array([0.08420479, 0.91579521])},
#  {'classes': 1, 'probabilities': array([0.14139187, 0.85860813])},
#  {'classes': 1, 'probabilities': array([0.1030297, 0.8969703])},
#  {'classes': 1, 'probabilities': array([0.13092002, 0.86907998])},
#  {'classes': 1, 'probabilities': array([0.19329723, 0.80670277])},
#  {'classes': 1, 'probabilities': array([0.11021769, 0.88978231])},
#  {'classes': 1, 'probabilities': array([0.18054586, 0.81945414])},
#  {'classes': 1, 'probabilities': array([0.15670249, 0.84329751])},
#  {'classes': 1, 'probabilities': array([0.16420199, 0.83579801])},
#  {'classes': 1, 'probabilities': array([0.139595, 0.860405])},
#  {'classes': 1, 'probabilities': array([0.11940381, 0.88059619])},
#  {'classes': 1, 'probabilities': array([0.10260495, 0.89739505])},
#  {'classes': 1, 'probabilities': array([0.14813651, 0.85186349])},
#  {'classes': 1, 'probabilities': array([0.13061732, 0.86938268])},
#  {'classes': 1, 'probabilities': array([0.11046306, 0.88953694])},
#  {'classes': 1, 'probabilities': array([0.10719717, 0.89280283])},
#  {'classes': 1, 'probabilities': array([0.1083186, 0.8916814])},
#  {'classes': 1, 'probabilities': array([0.0858136, 0.9141864])},
#  {'classes': 1, 'probabilities': array([0.19332736, 0.80667264])},
#  {'classes': 1, 'probabilities': array([0.07793483, 0.92206517])},
#  {'classes': 1, 'probabilities': array([0.22469134, 0.77530866])},
#  {'classes': 1, 'probabilities': array([0.10974864, 0.89025136])},
#  {'classes': 1, 'probabilities': array([0.1588598, 0.8411402])},
#  {'classes': 1, 'probabilities': array([0.08201859, 0.91798141])},
#  {'classes': 1, 'probabilities': array([0.06966824, 0.93033176])},
#  {'classes': 1, 'probabilities': array([0.05977735, 0.94022265])},
#  {'classes': 1, 'probabilities': array([0.05918903, 0.94081097])},
#  {'classes': 1, 'probabilities': array([0.13221774, 0.86778226])},
#  {'classes': 1, 'probabilities': array([0.1265154, 0.8734846])},
#  {'classes': 1, 'probabilities': array([0.17638638, 0.82361362])},
#  {'classes': 1, 'probabilities': array([0.13486208, 0.86513792])},
#  {'classes': 1, 'probabilities': array([0.09298735, 0.90701265])},
#  {'classes': 1, 'probabilities': array([0.22768604, 0.77231396])},
#  {'classes': 1, 'probabilities': array([0.15535849, 0.84464151])},
#  {'classes': 1, 'probabilities': array([0.08984065, 0.91015935])},
#  {'classes': 1, 'probabilities': array([0.08494432, 0.91505568])},
#  {'classes': 1, 'probabilities': array([0.1836702, 0.8163298])},
#  {'classes': 1, 'probabilities': array([0.06768343, 0.93231657])},
#  {'classes': 1, 'probabilities': array([0.07923771, 0.92076229])},
#  {'classes': 1, 'probabilities': array([0.09498184, 0.90501816])},
#  {'classes': 1, 'probabilities': array([0.14596527, 0.85403473])},
#  {'classes': 1, 'probabilities': array([0.13592687, 0.86407313])},
#  {'classes': 1, 'probabilities': array([0.1360251, 0.8639749])},
#  {'classes': 1, 'probabilities': array([0.05654027, 0.94345973])},
#  {'classes': 1, 'probabilities': array([0.122737, 0.877263])},
#  {'classes': 1, 'probabilities': array([0.14223714, 0.85776286])},
#  {'classes': 1, 'probabilities': array([0.11914904, 0.88085096])},
#  {'classes': 1, 'probabilities': array([0.0591439, 0.9408561])},
#  {'classes': 1, 'probabilities': array([0.18156354, 0.81843646])},
#  {'classes': 1, 'probabilities': array([0.19715862, 0.80284138])},
#  {'classes': 1, 'probabilities': array([0.14158465, 0.85841535])},
#  {'classes': 1, 'probabilities': array([0.07006178, 0.92993822])},
#  {'classes': 1, 'probabilities': array([0.11798711, 0.88201289])},
#  {'classes': 1, 'probabilities': array([0.15039441, 0.84960559])},
#  {'classes': 1, 'probabilities': array([0.19219023, 0.80780977])},
#  {'classes': 1, 'probabilities': array([0.06376271, 0.93623729])},
#  {'classes': 1, 'probabilities': array([0.11791835, 0.88208165])},
# ...
#  {'classes': 1, 'probabilities': array([0.09449533, 0.90550467])},
#  {'classes': 1, 'probabilities': array([0.09398047, 0.90601953])},
#  {'classes': 1, 'probabilities': array([0.15532901, 0.84467099])},
#  {'classes': 1, 'probabilities': array([0.12650364, 0.87349636])},
#  {'classes': 1, 'probabilities': array([0.16540149, 0.83459851])},
#  {'classes': 1, 'probabilities': array([0.07916989, 0.92083011])},
#  {'classes': 1, 'probabilities': array([0.16413975, 0.83586025])},
#  {'classes': 1, 'probabilities': array([0.20925449, 0.79074551])},
#  {'classes': 1, 'probabilities': array([0.07177996, 0.92822004])},
#  {'classes': 1, 'probabilities': array([0.07335747, 0.92664253])},
#  {'classes': 1, 'probabilities': array([0.09604476, 0.90395524])},
#  {'classes': 1, 'probabilities': array([0.17695006, 0.82304994])},
#  {'classes': 1, 'probabilities': array([0.19640773, 0.80359227])},
#  {'classes': 1, 'probabilities': array([0.14415086, 0.85584914])},
#  {'classes': 1, 'probabilities': array([0.17795227, 0.82204773])},
#  {'classes': 1, 'probabilities': array([0.17354191, 0.82645809])},
#  {'classes': 1, 'probabilities': array([0.14027214, 0.85972786])},
#  {'classes': 1, 'probabilities': array([0.12703153, 0.87296847])},
#  {'classes': 1, 'probabilities': array([0.0564094, 0.9435906])},
#  {'classes': 1, 'probabilities': array([0.13029269, 0.86970731])},
#  {'classes': 1, 'probabilities': array([0.13112149, 0.86887851])},
#  {'classes': 1, 'probabilities': array([0.126507, 0.873493])},
#  {'classes': 1, 'probabilities': array([0.14814954, 0.85185046])},
#  {'classes': 1, 'probabilities': array([0.16760858, 0.83239142])},
#  {'classes': 1, 'probabilities': array([0.10935103, 0.89064897])},
#  {'classes': 1, 'probabilities': array([0.17111307, 0.82888693])},
#  {'classes': 1, 'probabilities': array([0.11632937, 0.88367063])},
#  {'classes': 1, 'probabilities': array([0.09273078, 0.90726922])},
#  {'classes': 1, 'probabilities': array([0.16009294, 0.83990706])},
#  {'classes': 1, 'probabilities': array([0.11256328, 0.88743672])},
#  {'classes': 1, 'probabilities': array([0.1142335, 0.8857665])},
#  {'classes': 1, 'probabilities': array([0.12350803, 0.87649197])},
#  {'classes': 1, 'probabilities': array([0.05955503, 0.94044497])},
#  {'classes': 1, 'probabilities': array([0.12546067, 0.87453933])},
#  {'classes': 1, 'probabilities': array([0.06811307, 0.93188693])},
#  {'classes': 1, 'probabilities': array([0.16706246, 0.83293754])},
#  {'classes': 1, 'probabilities': array([0.15898219, 0.84101781])},
#  {'classes': 1, 'probabilities': array([0.09327198, 0.90672802])},
#  {'classes': 1, 'probabilities': array([0.11359061, 0.88640939])},
#  {'classes': 1, 'probabilities': array([0.09728693, 0.90271307])},
#  {'classes': 1, 'probabilities': array([0.15919709, 0.84080291])},
#  {'classes': 1, 'probabilities': array([0.09807612, 0.90192388])},
#  {'classes': 1, 'probabilities': array([0.21520065, 0.78479935])},
#  {'classes': 1, 'probabilities': array([0.11261552, 0.88738448])},
#  {'classes': 1, 'probabilities': array([0.14127865, 0.85872135])},
#  {'classes': 1, 'probabilities': array([0.13295224, 0.86704776])},
#  {'classes': 1, 'probabilities': array([0.13323944, 0.86676056])},
#  {'classes': 1, 'probabilities': array([0.09230183, 0.90769817])},
#  {'classes': 1, 'probabilities': array([0.12829938, 0.87170062])},
#  {'classes': 1, 'probabilities': array([0.12311749, 0.87688251])},
#  {'classes': 1, 'probabilities': array([0.09837794, 0.90162206])},
#  {'classes': 1, 'probabilities': array([0.10922725, 0.89077275])},
#  {'classes': 1, 'probabilities': array([0.08155023, 0.91844977])},
#  {'classes': 1, 'probabilities': array([0.11613014, 0.88386986])},
#  {'classes': 1, 'probabilities': array([0.11529832, 0.88470168])},
#  {'classes': 1, 'probabilities': array([0.14741233, 0.85258767])},
#  {'classes': 1, 'probabilities': array([0.14664381, 0.85335619])},
#  {'classes': 1, 'probabilities': array([0.12391338, 0.87608662])},
#  {'classes': 1, 'probabilities': array([0.12506686, 0.87493314])},
#  {'classes': 1, 'probabilities': array([0.10558055, 0.89441945])},
#  {'classes': 1, 'probabilities': array([0.14664381, 0.85335619])},
#  {'classes': 1, 'probabilities': array([0.10974807, 0.89025193])},
#  {'classes': 1, 'probabilities': array([0.17960227, 0.82039773])},
#  {'classes': 1, 'probabilities': array([0.11772914, 0.88227086])},
#  {'classes': 1, 'probabilities': array([0.15003658, 0.84996342])},
#  {'classes': 1, 'probabilities': array([0.15255568, 0.84744432])},
#  {'classes': 1, 'probabilities': array([0.15572511, 0.84427489])},
#  {'classes': 1, 'probabilities': array([0.07338747, 0.92661253])},
#  {'classes': 1, 'probabilities': array([0.19112451, 0.80887549])},
#  {'classes': 1, 'probabilities': array([0.08358863, 0.91641137])},
#  {'classes': 1, 'probabilities': array([0.09477479, 0.90522521])},
#  {'classes': 1, 'probabilities': array([0.12216467, 0.87783533])},
#  {'classes': 1, 'probabilities': array([0.11519151, 0.88480849])},
#  {'classes': 1, 'probabilities': array([0.08880792, 0.91119208])},
#  {'classes': 1, 'probabilities': array([0.16580645, 0.83419355])},
#  {'classes': 1, 'probabilities': array([0.13952587, 0.86047413])},
#  {'classes': 1, 'probabilities': array([0.11451105, 0.88548895])},
#  {'classes': 1, 'probabilities': array([0.09431031, 0.90568969])},
#  {'classes': 1, 'probabilities': array([0.09610644, 0.90389356])},
#  {'classes': 1, 'probabilities': array([0.10204546, 0.89795454])},
#  {'classes': 1, 'probabilities': array([0.19830332, 0.80169668])},
#  {'classes': 1, 'probabilities': array([0.15145898, 0.84854102])},
#  {'classes': 1, 'probabilities': array([0.23130109, 0.76869891])},
#  {'classes': 1, 'probabilities': array([0.16761101, 0.83238899])},
#  {'classes': 1, 'probabilities': array([0.09756146, 0.90243854])},
#  {'classes': 1, 'probabilities': array([0.12856833, 0.87143167])},
#  {'classes': 1, 'probabilities': array([0.16627267, 0.83372733])},
#  {'classes': 1, 'probabilities': array([0.14166502, 0.85833498])},
#  {'classes': 1, 'probabilities': array([0.14826235, 0.85173765])},
#  {'classes': 1, 'probabilities': array([0.20307446, 0.79692554])},
#  {'classes': 1, 'probabilities': array([0.15104021, 0.84895979])},
#  {'classes': 1, 'probabilities': array([0.12175969, 0.87824031])},
#  {'classes': 1, 'probabilities': array([0.10020242, 0.89979758])},
#  {'classes': 1, 'probabilities': array([0.08822162, 0.91177838])},
#  {'classes': 1, 'probabilities': array([0.17749487, 0.82250513])},
#  {'classes': 1, 'probabilities': array([0.09506098, 0.90493902])},
#  {'classes': 1, 'probabilities': array([0.07052323, 0.92947677])},
#  {'classes': 1, 'probabilities': array([0.09549291, 0.90450709])},
#  {'classes': 1, 'probabilities': array([0.12631703, 0.87368297])},
#  {'classes': 1, 'probabilities': array([0.15466758, 0.84533242])},
#  {'classes': 1, 'probabilities': array([0.09832243, 0.90167757])},
#  {'classes': 1, 'probabilities': array([0.16200721, 0.83799279])},
#  {'classes': 1, 'probabilities': array([0.14623545, 0.85376455])},
#  {'classes': 1, 'probabilities': array([0.13943558, 0.86056442])},
#  {'classes': 1, 'probabilities': array([0.17954554, 0.82045446])},
#  {'classes': 1, 'probabilities': array([0.09190914, 0.90809086])},
#  {'classes': 1, 'probabilities': array([0.09273078, 0.90726922])},
#  {'classes': 1, 'probabilities': array([0.12645574, 0.87354426])},
#  {'classes': 1, 'probabilities': array([0.18529378, 0.81470622])},
#  {'classes': 1, 'probabilities': array([0.10599941, 0.89400059])},
#  {'classes': 1, 'probabilities': array([0.12663435, 0.87336565])},
#  {'classes': 1, 'probabilities': array([0.12133874, 0.87866126])},
#  {'classes': 1, 'probabilities': array([0.05306963, 0.94693037])},
#  {'classes': 1, 'probabilities': array([0.09077183, 0.90922817])},
#  {'classes': 1, 'probabilities': array([0.14472712, 0.85527288])},
#  {'classes': 1, 'probabilities': array([0.12927251, 0.87072749])},
#  {'classes': 1, 'probabilities': array([0.12897175, 0.87102825])},
#  {'classes': 1, 'probabilities': array([0.20260484, 0.79739516])},
#  {'classes': 1, 'probabilities': array([0.12920935, 0.87079065])},
#  {'classes': 1, 'probabilities': array([0.16540222, 0.83459778])},
#  {'classes': 1, 'probabilities': array([0.13271804, 0.86728196])},
#  {'classes': 1, 'probabilities': array([0.12206317, 0.87793683])},
#  {'classes': 1, 'probabilities': array([0.07672587, 0.92327413])},
#  {'classes': 1, 'probabilities': array([0.07291424, 0.92708576])},
#  {'classes': 1, 'probabilities': array([0.09433578, 0.90566422])},
#  {'classes': 1, 'probabilities': array([0.10488626, 0.89511374])},
#  {'classes': 1, 'probabilities': array([0.12511907, 0.87488093])},
#  {'classes': 1, 'probabilities': array([0.1122747, 0.8877253])},
#  {'classes': 1, 'probabilities': array([0.12585746, 0.87414254])},
#  {'classes': 1, 'probabilities': array([0.11855657, 0.88144343])},
#  {'classes': 1, 'probabilities': array([0.13653404, 0.86346596])},
#  {'classes': 1, 'probabilities': array([0.07352676, 0.92647324])},
#  {'classes': 1, 'probabilities': array([0.10664758, 0.89335242])},
#  {'classes': 1, 'probabilities': array([0.12478034, 0.87521966])},
#  {'classes': 1, 'probabilities': array([0.12197772, 0.87802228])},
#  {'classes': 1, 'probabilities': array([0.14422327, 0.85577673])},
#  {'classes': 1, 'probabilities': array([0.13758762, 0.86241238])},
#  {'classes': 1, 'probabilities': array([0.16169804, 0.83830196])},
#  {'classes': 1, 'probabilities': array([0.13774555, 0.86225445])},
#  {'classes': 1, 'probabilities': array([0.06510568, 0.93489432])},
#  {'classes': 1, 'probabilities': array([0.1836702, 0.8163298])},
#  {'classes': 1, 'probabilities': array([0.12297608, 0.87702392])},
#  {'classes': 1, 'probabilities': array([0.1440563, 0.8559437])},
#  {'classes': 1, 'probabilities': array([0.13985775, 0.86014225])},
#  {'classes': 1, 'probabilities': array([0.15248417, 0.84751583])},
#  {'classes': 1, 'probabilities': array([0.16583933, 0.83416067])},
#  {'classes': 1, 'probabilities': array([0.06138169, 0.93861831])},
#  {'classes': 1, 'probabilities': array([0.16290962, 0.83709038])},
#  {'classes': 1, 'probabilities': array([0.14664381, 0.85335619])},
#  {'classes': 1, 'probabilities': array([0.13303153, 0.86696847])},
#  {'classes': 1, 'probabilities': array([0.12970513, 0.87029487])},
#  {'classes': 1, 'probabilities': array([0.12185988, 0.87814012])},
#  {'classes': 1, 'probabilities': array([0.13844868, 0.86155132])},
#  {'classes': 1, 'probabilities': array([0.12006304, 0.87993696])},
#  {'classes': 1, 'probabilities': array([0.08275842, 0.91724158])},
#  {'classes': 1, 'probabilities': array([0.148727, 0.851273])},
#  {'classes': 1, 'probabilities': array([0.25123959, 0.74876041])},
#  {'classes': 1, 'probabilities': array([0.16368745, 0.83631255])},
#  {'classes': 1, 'probabilities': array([0.08637819, 0.91362181])},
#  {'classes': 1, 'probabilities': array([0.14826235, 0.85173765])},
#  {'classes': 1, 'probabilities': array([0.17120885, 0.82879115])},
#  {'classes': 1, 'probabilities': array([0.18230457, 0.81769543])},
#  {'classes': 1, 'probabilities': array([0.20217374, 0.79782626])},
#  {'classes': 1, 'probabilities': array([0.13218492, 0.86781508])},
#  {'classes': 1, 'probabilities': array([0.17684506, 0.82315494])},
#  {'classes': 1, 'probabilities': array([0.15146109, 0.84853891])},
#  {'classes': 1, 'probabilities': array([0.14984065, 0.85015935])},
#  {'classes': 1, 'probabilities': array([0.17114125, 0.82885875])},
#  {'classes': 1, 'probabilities': array([0.1717224, 0.8282776])},
#  {'classes': 1, 'probabilities': array([0.17488025, 0.82511975])},
#  {'classes': 1, 'probabilities': array([0.08844511, 0.91155489])},
#  {'classes': 1, 'probabilities': array([0.12278853, 0.87721147])},
#  {'classes': 1, 'probabilities': array([0.0792976, 0.9207024])},
#  {'classes': 1, 'probabilities': array([0.0949769, 0.9050231])},
#  {'classes': 1, 'probabilities': array([0.1684809, 0.8315191])},
#  {'classes': 1, 'probabilities': array([0.1856165, 0.8143835])},
#  {'classes': 1, 'probabilities': array([0.10823947, 0.89176053])},
#  {'classes': 1, 'probabilities': array([0.07864211, 0.92135789])},
#  {'classes': 1, 'probabilities': array([0.14178505, 0.85821495])},
#  {'classes': 1, 'probabilities': array([0.15405842, 0.84594158])},
#  {'classes': 1, 'probabilities': array([0.09904354, 0.90095646])},
#  {'classes': 1, 'probabilities': array([0.09317007, 0.90682993])},
#  {'classes': 1, 'probabilities': array([0.15447617, 0.84552383])},
#  {'classes': 1, 'probabilities': array([0.15559591, 0.84440409])},
#  {'classes': 1, 'probabilities': array([0.12939243, 0.87060757])},
#  {'classes': 1, 'probabilities': array([0.12003829, 0.87996171])},
#  {'classes': 1, 'probabilities': array([0.15978322, 0.84021678])},
#  {'classes': 1, 'probabilities': array([0.11361723, 0.88638277])},
#  {'classes': 1, 'probabilities': array([0.13840267, 0.86159733])},
#  {'classes': 1, 'probabilities': array([0.073755, 0.926245])},
#  {'classes': 1, 'probabilities': array([0.07327674, 0.92672326])},
#  {'classes': 1, 'probabilities': array([0.18270568, 0.81729432])},
#  {'classes': 1, 'probabilities': array([0.1268301, 0.8731699])},
#  {'classes': 1, 'probabilities': array([0.09154083, 0.90845917])},
#  {'classes': 1, 'probabilities': array([0.15887087, 0.84112913])},
#  {'classes': 1, 'probabilities': array([0.0854363, 0.9145637])},
#  {'classes': 1, 'probabilities': array([0.17007808, 0.82992192])},
#  {'classes': 1, 'probabilities': array([0.09633399, 0.90366601])},
#  {'classes': 1, 'probabilities': array([0.07754968, 0.92245032])},
#  {'classes': 1, 'probabilities': array([0.09410607, 0.90589393])},
#  {'classes': 1, 'probabilities': array([0.13556173, 0.86443827])},
#  {'classes': 1, 'probabilities': array([0.1503875, 0.8496125])},
#  {'classes': 1, 'probabilities': array([0.15583995, 0.84416005])},
#  {'classes': 1, 'probabilities': array([0.04352321, 0.95647679])},
#  {'classes': 1, 'probabilities': array([0.11266423, 0.88733577])},
#  {'classes': 1, 'probabilities': array([0.1383559, 0.8616441])},
#  {'classes': 1, 'probabilities': array([0.08073461, 0.91926539])},
#  {'classes': 1, 'probabilities': array([0.0709116, 0.9290884])},
#  {'classes': 1, 'probabilities': array([0.08900821, 0.91099179])},
#  {'classes': 1, 'probabilities': array([0.09625165, 0.90374835])},
#  {'classes': 1, 'probabilities': array([0.09273078, 0.90726922])},
#  {'classes': 1, 'probabilities': array([0.06510574, 0.93489426])},
#  {'classes': 1, 'probabilities': array([0.12134368, 0.87865632])},
#  {'classes': 1, 'probabilities': array([0.11865263, 0.88134737])},
#  {'classes': 1, 'probabilities': array([0.08715512, 0.91284488])},
#  {'classes': 1, 'probabilities': array([0.11818794, 0.88181206])},
#  {'classes': 1, 'probabilities': array([0.16489335, 0.83510665])},
#  {'classes': 1, 'probabilities': array([0.15370055, 0.84629945])},
#  {'classes': 1, 'probabilities': array([0.1115623, 0.8884377])},
#  {'classes': 1, 'probabilities': array([0.13180644, 0.86819356])},
#  {'classes': 1, 'probabilities': array([0.11502151, 0.88497849])},
#  {'classes': 1, 'probabilities': array([0.1308763, 0.8691237])},
#  {'classes': 1, 'probabilities': array([0.16325628, 0.83674372])},
#  {'classes': 1, 'probabilities': array([0.04511538, 0.95488462])},
#  {'classes': 1, 'probabilities': array([0.08656371, 0.91343629])},
#  {'classes': 1, 'probabilities': array([0.13765494, 0.86234506])},
#  {'classes': 1, 'probabilities': array([0.1181516, 0.8818484])},
#  {'classes': 1, 'probabilities': array([0.0969489, 0.9030511])},
#  {'classes': 1, 'probabilities': array([0.12552765, 0.87447235])},
#  {'classes': 1, 'probabilities': array([0.25688234, 0.74311766])},
#  {'classes': 1, 'probabilities': array([0.14895453, 0.85104547])},
#  {'classes': 1, 'probabilities': array([0.09569194, 0.90430806])},
#  {'classes': 1, 'probabilities': array([0.15980655, 0.84019345])},
#  {'classes': 1, 'probabilities': array([0.14262363, 0.85737637])},
#  {'classes': 1, 'probabilities': array([0.16183511, 0.83816489])},
#  {'classes': 1, 'probabilities': array([0.08401311, 0.91598689])},
#  {'classes': 1, 'probabilities': array([0.12602798, 0.87397202])},
#  {'classes': 1, 'probabilities': array([0.15069034, 0.84930966])},
#  {'classes': 1, 'probabilities': array([0.08890756, 0.91109244])},
#  ...]
